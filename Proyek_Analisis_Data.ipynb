# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** Dorothy Putri Elvira
# - **Email:** dorothyputrielv@gmail
# - **ID Dicoding:** [Input Username]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# - **Pertanyaan 1:** Bagaimana tren rata-rata konsentrasi polutan PM2.5 secara bulanan di stasiun Dongsi sepanjang tahun 2015, dan pada bulan apa polusi mencapai tingkat tertinggi
# Keterangan:
#   1.   Specific : Fokus ke polutan PM2.5 di stasiun spesifik (Dongsi).
#
#   2.   Measurable : Diukur dengan angka rata-rata konsentrasi per bulan.
#
#   3.   Action-Oriented : Jika ketahuan bulan apa yang paling polutif, pemerintah/warga bisa mengambil aksi pencegahan (misal: pembatasan industri atau anjuran pakai masker di bulan tersebut).
#
#   4.   Relevant : Sangat relevan dengan tujuan analisis kualitas udara dan dampak kesehatan.
#
#   5.   Time-bound : Dibatasi hanya sepanjang tahun 2015
# - **Pertanyaan 2:** "Apakah terdapat korelasi antara suhu udara (TEMP) dengan kadar gas rumah kaca sulfur dioksida (SO2) di seluruh stasiun pemantauan selama periode tahun 2016?"
# Keterangan:
#   1.   Specific: Menguji hubungan antara variabel cuaca harian (TEMP) dan polutan spesifik (SO2).
#
#   2.   Measurable: Bisa diukur secara konkret menggunakan koefisien korelasi atau grafik scatterplot.
#
#   3.   Action-Oriented: Membantu tim analis memprediksi lonjakan zat kimia berbahaya berdasarkan perubahan suhu/musim.
#
#   4.  Relevant: Relevan untuk memahami pola penyebaran polusi akibat faktor alam.
#
#   5.  Time-bound: Dibatasi khusus pada data tahun 2016.
#
# *   **Pertanyaan 3**: "Stasiun mana yang memiliki rata-rata tingkat polusi PM2.5 tertinggi dan bagaimana karakteristik perbedaan distribusi polusi antar stasiun pengamatan tersebut?" Keterangan
#     1.   Specific: Fokus membandingkan tingkat polusi PM2.5 di antara berbagai lokasi stasiun.
#
#     2.   Measurable: Diukur dengan melihat nilai frekuensi data (value_counts) dan perbandingan sebaran nilai lewat Boxplot atau Violin Plot.
#
#     3.   Action-Oriented: Membantu mengidentifikasi wilayah stasiun mana yang paling kritis sehingga alokasi alat pembersih udara atau kebijakan pembatasan industri bisa diprioritaskan ke stasiun tersebut.
#
#     4.  Relevant: Sangat sejalan dengan manajemen kualitas udara regional.
#
#     5.  Time-bound: Menggunakan keseluruhan rentang data yang tersedia di dataset.

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats  # Digunakan untuk analisis Q-Q Plot dan uji normalitas nanti

# Mengatur agar visualisasi Seaborn terlihat lebih rapi dan konsisten
sns.set_theme(style="whitegrid")

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# #### Load df ...

# %%
import pandas as pd
import glob

# Mengambil semua file yang berakhiran .csv di direktori utama Colab
path_files = glob.glob('*.csv')

# Menggabungkan semua file CSV menjadi satu DataFrame
df_list = [pd.read_csv(file) for file in path_files]
air_quality_df = pd.concat(df_list, ignore_index=True)

# Cek jumlah baris data yang berhasil digabungkan
print(f"Total data dari seluruh stasiun: {air_quality_df.shape[0]} baris")
air_quality_df.head()
# Out:
# Total data dari seluruh stasiun: 420768 baris
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Identifying ... problem

# %%
# Cek info dataframe untuk melihat tipe data dan jumlah data non-null
print("--- INFO DATAFRAME ---")
air_quality_df.info()

# Cek jumlah missing values di setiap kolom
print("\n--- JUMLAH MISSING VALUES ---")
print(air_quality_df.isna().sum())

# Cek jumlah data yang duplikat
print("\n--- JUMLAH DATA DUPLIKAT ---")
print(f"Total data duplikat: {air_quality_df.duplicated().sum()}")
# Out:
# --- INFO DATAFRAME ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420768 entries, 0 to 420767
# Data columns (total 18 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   No       420768 non-null  int64
#  1   year     420768 non-null  int64
#  2   month    420768 non-null  int64
#  3   day      420768 non-null  int64
#  4   hour     420768 non-null  int64
#  5   PM2.5    412029 non-null  float64
#  6   PM10     414319 non-null  float64
#  7   SO2      411747 non-null  float64
#  8   NO2      408652 non-null  float64
#  9   CO       400067 non-null  float64
#  10  O3       407491 non-null  float64
#  11  TEMP     420370 non-null  float64
#  12  PRES     420375 non-null  float64
#  13  DEWP     420365 non-null  float64
#  14  RAIN     420378 non-null  float64
#  15  wd       418946 non-null  object
#  16  WSPM     420450 non-null  float64
#  17  station  420768 non-null  object
# dtypes: float64(11), int64(5), object(2)
# ...

# %% [markdown]
# **Steps to Take:**
# - xxx
# - xxx

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Fixing ... problem

# %%
# 1. Mengatasi Missing Values dengan metode Forward Fill (mengisi dengan nilai jam sebelumnya)
air_quality_df.ffill(inplace=True)

# Jika masih ada sisa kosong di baris paling awal sekali, isi dengan nilai setelahnya (Backward Fill)
air_quality_df.bfill(inplace=True)

# 2. Menggabungkan kolom year, month, day, hour menjadi satu kolom datetime standar
air_quality_df['datetime'] = pd.to_datetime(air_quality_df[['year', 'month', 'day', 'hour']])

# 3. Memastikan data benar-benar sudah bersih 100%
print("=== PENGECEKAN ULANG SETELAH CLEANING ===")
print(f"Jumlah missing values sekarang: {air_quality_df.isnull().sum().sum()}")
# Out:
# === PENGECEKAN ULANG SETELAH CLEANING ===
# Jumlah missing values sekarang: 0

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
import scipy.stats as stats

# ==============================================================================
# 1. EDA UNIVARIATE (Histogram, KDE, Boxplot, Skewness & Kurtosis)
# ==============================================================================
print("--- 1. EDA UNIVARIATE ---")

# Menentukan kolom numerik utama untuk dianalisis distribusinya
num_cols = ['PM2.5', 'PM10', 'SO2', 'TEMP', 'PRES']

for col in num_cols:
    # Membuat subplots: 1 baris, 2 kolom grafik
    fig, axes = plt.subplots(1, 2, figsize=(14, 4))

    # Grafik Kiri: Histogram + KDE (Kurva Halus Sebaran Data)
    sns.histplot(air_quality_df[col], kde=True, ax=axes[0], color='skyblue')
    axes[0].set_title(f'Distribusi & KDE {col}')
    axes[0].set_xlabel(col)
    axes[0].set_ylabel('Frequency')

    # Grafik Kanan: Boxplot (Melihat Kuartil, Median, dan Outliers)
    sns.boxplot(x=air_quality_df[col], ax=axes[1], color='salmon')
    axes[1].set_title(f'Boxplot {col}')
    axes[1].set_xlabel(col)

    plt.tight_layout()
    plt.show()

# Analisis Bentuk Distribusi (Skewness & Kurtosis)
print("\n[Analisis Skewness & Kurtosis]")
for col in num_cols:
    print(f"Kolom {col:5} -> Skewness: {air_quality_df[col].skew():.2f} | Kurtosis: {air_quality_df[col].kurt():.2f}")


# ==============================================================================
# 2. EDA MULTIVARIATE & NUMERIKAL (Correlation Heatmap & Percentiles)
# ==============================================================================
print("\n--- 2. EDA MULTIVARIATE & NUMERIKAL ---")

# Korelasi Comprehensive untuk semua variabel numerik
all_num_cols = ['PM2.5', 'PM10', 'SO2', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']

plt.figure(figsize=(10, 8))
corr_matrix = air_quality_df[all_num_cols].corr()

# Correlation Matrix Heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix Heatmap", fontsize=14)
plt.show()

# Detailed Percentile Analysis untuk PM2.5 (Menjawab permintaan penilai)
print("\n[Detailed Percentile Analysis PM2.5]")
print(air_quality_df['PM2.5'].quantile([0.05, 0.10, 0.25, 0.50, 0.75, 0.90, 0.95]))

# Q-Q Plot untuk menguji Normality Distribusi PM2.5
plt.figure(figsize=(6, 4))
stats.probplot(air_quality_df['PM2.5'], dist="norm", plot=plt)
plt.title("Q-Q Plot - PM2.5 Normality Test")
plt.show()


# ==============================================================================
# 3. EDA KATEGORIKAL (Value Counts, Bar Plot, & Boxplot per Station)
# ==============================================================================
print("\n--- 3. EDA KATEGORIKAL (Menjawab Pertanyaan 3) ---")

# A. Value Counts & Bar Plot (Distribusi frekuensi data per stasiun)
plt.figure(figsize=(12, 4))
sns.countplot(data=air_quality_df, x='station', palette='viridis', order=air_quality_df['station'].value_counts().index)
plt.title("Distribusi Frekuensi Data per Stasiun (Value Counts)", fontsize=12)
plt.xticks(rotation=45)
plt.xlabel("Nama Stasiun")
plt.ylabel("Jumlah Baris Data")
plt.show()

# B. Box Plot per Kategori (Distribusi PM2.5 di setiap stasiun berbeda)
plt.figure(figsize=(14, 6))
sns.boxplot(data=air_quality_df, x='station', y='PM2.5', palette='Set3')
plt.title("Distribusi dan Sebaran Polusi PM2.5 di Berbagai Stasiun", fontsize=12)
plt.xticks(rotation=45)
plt.xlabel("Nama Stasiun")
plt.ylabel("Konsentrasi PM2.5")
plt.show()

# C. Variance, Standard Deviation, & Mean Analysis per Station
print("\n[Variabilitas Kualitas Udara (PM2.5) per Stasiun]")
station_profile = air_quality_df.groupby('station')['PM2.5'].agg(['mean', 'std', 'var', 'min', 'max'])
print(station_profile)
# Out:
# --- 1. EDA UNIVARIATE ---
# [Analisis Skewness & Kurtosis]
# Kolom PM2.5 -> Skewness: 2.01 | Kurtosis: 5.90
# Kolom PM10  -> Skewness: 1.94 | Kurtosis: 6.63
# Kolom SO2   -> Skewness: 3.79 | Kurtosis: 34.23
# Kolom TEMP  -> Skewness: -0.10 | Kurtosis: -1.14
# Kolom PRES  -> Skewness: 0.11 | Kurtosis: -0.83
#
# --- 2. EDA MULTIVARIATE & NUMERIKAL ---
# [Detailed Percentile Analysis PM2.5]
# 0.05      6.0
# 0.10      9.0
# 0.25     20.0
# 0.50     55.0
# 0.75    112.0
# 0.90    186.0
# 0.95    243.0
# Name: PM2.5, dtype: float64
# --- 3. EDA KATEGORIKAL (Menjawab Pertanyaan 3) ---
# /tmp/ipykernel_5939/1287269648.py:69: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=air_quality_df, x='station', palette='viridis', order=air_quality_df['station'].value_counts().index)
# /tmp/ipykernel_5939/1287269648.py:78: FutureWarning:
#
# ...

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
# 1. Filter data khusus untuk Stasiun Dongsi di tahun 2015
df_p1 = air_quality_df[(air_quality_df['station'] == 'Dongsi') & (air_quality_df['year'] == 2015)]

# 2. Grouping berdasarkan bulan dan hitung rata-rata PM2.5
monthly_pm25 = df_p1.groupby('month')['PM2.5'].mean().reset_index()

# 3. Membuat grafik tren garis
plt.figure(figsize=(10, 5))
sns.lineplot(data=monthly_pm25, x='month', y='PM2.5', marker='o', color='darkred', linewidth=2.5)

plt.title("Tren Rata-Rata Konsentrasi PM2.5 Per Bulan di Stasiun Dongsi (2015)", fontsize=13)
plt.xlabel("Bulan", fontsize=11)
plt.ylabel("Rata-Rata PM2.5 (µg/m³)", fontsize=11)
plt.xticks(range(1, 13)) # Memastikan angka bulan muncul 1 sampai 12
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
# 1. Filter data untuk tahun 2016 di seluruh stasiun
df_p2 = air_quality_df[air_quality_df['year'] == 2016]

# 2. Membuat Scatter Plot dengan Regression Line
plt.figure(figsize=(10, 6))
sns.regplot(data=df_p2, x='TEMP', y='SO2',
            scatter_kws={'alpha': 0.2, 'color': 'teal', 's': 10},
            line_kws={'color': 'coral', 'linewidth': 2})

# 3. Hitung nilai korelasi Pearson secara spesifik untuk memperkuat insight
correlation = df_p2['TEMP'].corr(df_p2['SO2'])

plt.title(f"Hubungan Suhu Udara (TEMP) vs Kadar SO2 - Semua Stasiun (2016)\nNilai Korelasi Pearson: {correlation:.2f}", fontsize=13)
plt.xlabel("Suhu Udara (TEMP dalam °C)", fontsize=11)
plt.ylabel("Kadar Sulfur Dioksida (SO2)", fontsize=11)
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ### Pertanyaan 3:

# %%
# 1. Hitung rata-rata PM2.5 untuk setiap stasiun, lalu urutkan dari yang tertinggi
station_ranking = air_quality_df.groupby('station')['PM2.5'].mean().reset_index()
station_ranking = station_ranking.sort_values(by='PM2.5', ascending=False)

# 2. Membuat Bar Plot menggunakan Seaborn
plt.figure(figsize=(12, 5))
sns.barplot(data=station_ranking, x='station', y='PM2.5', palette='Reds_r')

plt.title("Peringkat Rata-Rata Tingkat Polusi PM2.5 Berdasarkan Stasiun Pengamatan", fontsize=13)
plt.xlabel("Stasiun Pengamatan", fontsize=11)
plt.ylabel("Rata-Rata PM2.5 (µg/m³)", fontsize=11)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_5939/2838696949.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=station_ranking, x='station', y='PM2.5', palette='Reds_r')

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Conclusion & Recommendation

# %% [markdown]
# - **Conclusion pertanyaan 1:** Pola musiman mempengaruhi peningkatan polusi PM2.5 dimana:
#     *   Kadar PM2.5 melonjak pada akhir dan awal tahun (puncaknya ada di Musim Dingin dimana kada PM2.5 di bulan Desember mencapai rata-rata tertinggi sebesar 161.24 $\mu\text{g/m}^3$)
#     *   cenderung menurun dan berada di titik terendah pada pertengahan tahun (Musim Panas), khususnya pada bulan Agustus yang menyentuh angka terendah yaitu 49.76 $\mu\text{g/m}^3$.
# - **Conclusion pertanyaan 1:** Terdapat korelasi negatif yang lemah hingga moderat antara suhu udara dan konsentrasi $\text{SO}_2$. Semakin rendah suhu udara (dingin), konsentrasi gas $\text{SO}_2$ di udara cenderung meningkat. Sebaliknya, saat suhu udara tinggi (panas), konsentrasi $\text{SO}_2$ cenderung lebih rendah dan melandai (sebagaimana ditunjukkan oleh garis tren merah yang menurun).
# - **Conclusion pertanyaan 2:** Hubungan antara tren PM2.5 yang tinggi di musim dingin dan korelasi negatif $\text{SO}_2$ terhadap suhu dapat memperburuk kualitas udara. Hal ini kemungkinan besar dipengaruhi oleh faktor meteorologi (seperti inversi suhu yang menjebak polutan) atau meningkatnya aktivitas pemanas ruangan berbahan bakar fosil (seperti batu bara) selama musim dingin di wilayah tersebut
# - **Conclusion pertanyaan 3:** Berdasarkan analisis peringkat rata-rata konsentrasi polutan PM2.5 di seluruh lokasi pengamatan, diperoleh kesimpulan sebagai berikut:
#   *   Stasiun dengan tingkat polusi PM2.5 tertinggi adalah Stasiun Dongsi, diikuti secara ketat oleh Wanshouxigong dan Nongzhanguan. Wilayah-wilayah stasiun ini perlu mendapatkan prioritas utama dalam kebijakan mitigasi polusi atau pembatasan emisi.
#   *   Stasiun dengan tingkat kualitas udara terbaik (paling bersih) adalah Stasiun Dingling, yang mencatatkan rata-rata konsentrasi PM2.5 paling minimum di antara 12 stasiun pengamatan yang ada.
#   *   Secara keseluruhan, perbedaan sebaran data menunjukkan polusi udara berada pada level yang cukup merata dan tinggi di sebagian besar stasiun (berkisar antara 70-85 µg/m³), mengindikasikan adanya tantangan kualitas udara skala regional.

# %% [markdown]
# **Rekomendasi Action Item:**
# - **Alokasi Sumber Daya Prioritas (Berdasarkan Pertanyaan 3)**:
#   Pemerintah regional harus memberikan perhatian dan alokasi anggaran khusus untuk stasiun Dongsi, Wanshouxigong, dan Nongzhanguan (misalnya dengan memperbanyak ruang terbuka hijau, memasang sensor pemantau tambahan, atau membatasi volume kendaraan berat di area tersebut) karena wilayah ini terbukti memiliki rata-rata polusi PM2.5 tertinggi.
# - **Manajemen Risiko Musiman & Peringatan Dini (Berdasarkan Pertanyaan 1)**:
#   Dikarenakan adanya lonjakan polusi ekstrem yang bersifat musiman di akhir tahun (mencapai puncaknya pada Bulan Desember), dinas kesehatan dan lingkungan setempat disarankan untuk merilis Early Warning System (Sistem Peringatan Dini) kepada masyarakat untuk memperketat penggunaan masker medis di bulan-bulan tersebut dan membatasi aktivitas luar ruangan bagi kelompok rentan (anak-anak dan lansia).

# %%
# 1. Menyimpan dataframe yang sudah bersih menjadi file main_data.csv
air_quality_df.to_csv("main_data.csv", index=False)
print("File main_data.csv berhasil dibuat di Colab!")

# 2. Mengunduh file main_data.csv ke laptop kamu
from google.colab import files
files.download("main_data.csv")
# Out:
# File main_data.csv berhasil dibuat di Colab!
